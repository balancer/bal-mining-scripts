# %% [markdown]
# # GNO hypothetical distribution analysis

# %%
import pandas as pd
series = pd.read_json(
    '__ethereum_0x6810e776880c02933d47db1b9fc05908e5386b96.json', 
    typ='series', 
    convert_dates=False)
series.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
series.describe()
# Out:
# count    2.110000e+02
# mean     2.843602e-01
# std      2.558148e+00
# min      4.300000e-07
# 25%      1.647000e-05
# 50%      1.418100e-04
# 75%      1.049390e-03
# max      2.687504e+01
# dtype: float64

# %%
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
series.sort_values(ascending=False).head(15)
# Out:
# 0xA6468eca7633246Dcb24E5599681767D27d1F978    26.875043
# 0x158772F59Fe0d3b75805fC11139b46CBc89F70e5    25.683844
# 0xF64C2E6679E089cD1c3e303CA1245d4941747700     2.548424
# 0x45602BFBA960277bF917C1b2007D1f03d7bd29e4     1.208810
# 0xD142c9cfE2F0BEF4c14594358fB65aeE1B726d2C     0.655925
# 0x39D787fdf7384597C7208644dBb6FDa1CcA4eBdf     0.570060
# 0x0154d25120Ed20A516fE43991702e7463c5A6F6e     0.496117
# 0xed9C851aAdf96d4Ff2Fab2433BC4AA111BabC15E     0.468004
# 0xeC576a26335dE1C360d2FC9A68cbA6BA37af4a13     0.294576
# 0x3A11F4c84688a1264690d696D8D807a25Ee02dd2     0.280578
# 0x69bAb6810fa99475854bca0A3DD72aE6a0728ECE     0.149792
# 0x34676cE24F37E1421A429481FEBe0bAcB2bC12f7     0.105399
# 0x63748140C409b490952c37daE5a60715Bf915129     0.071470
# 0x727334D71c7A70f8B611Cb32Da399048B4d27293     0.067251
# 0x9FE9986144655376e8F712E757e135492D6aeFe7     0.066821
# dtype: float64

# %% [markdown]
# # COW hypothetical distribution analysis

# %%
import pandas as pd
series = pd.read_json(
    '__ethereum_0xdef1ca1fb7fbcdc777520aa7f396b4e015f497ab.json', 
    typ='series', 
    convert_dates=False)
series.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
series.describe()
# Out:
# count      211.000000
# mean       284.360190
# std       2558.148137
# min          0.000429
# 25%          0.016473
# 50%          0.141810
# 75%          1.049393
# max      26875.042531
# dtype: float64

# %%
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
series.sort_values(ascending=False).head(15)
# Out:
# 0xA6468eca7633246Dcb24E5599681767D27d1F978    26875.042531
# 0x158772F59Fe0d3b75805fC11139b46CBc89F70e5    25683.843736
# 0xF64C2E6679E089cD1c3e303CA1245d4941747700     2548.424436
# 0x45602BFBA960277bF917C1b2007D1f03d7bd29e4     1208.809959
# 0xD142c9cfE2F0BEF4c14594358fB65aeE1B726d2C      655.924949
# 0x39D787fdf7384597C7208644dBb6FDa1CcA4eBdf      570.060237
# 0x0154d25120Ed20A516fE43991702e7463c5A6F6e      496.117205
# 0xed9C851aAdf96d4Ff2Fab2433BC4AA111BabC15E      468.004238
# 0xeC576a26335dE1C360d2FC9A68cbA6BA37af4a13      294.575824
# 0x3A11F4c84688a1264690d696D8D807a25Ee02dd2      280.577637
# 0x69bAb6810fa99475854bca0A3DD72aE6a0728ECE      149.792282
# 0x34676cE24F37E1421A429481FEBe0bAcB2bC12f7      105.398955
# 0x63748140C409b490952c37daE5a60715Bf915129       71.470151
# 0x727334D71c7A70f8B611Cb32Da399048B4d27293       67.251053
# 0x9FE9986144655376e8F712E757e135492D6aeFe7       66.820737
# dtype: float64
